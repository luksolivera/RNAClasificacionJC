# %% [markdown]
# <a href="https://colab.research.google.com/github/luksolivera/RNAClasificacionJC/blob/master/UNLP_Ejercicio_3_Redes_Neuronales_con_Keras_y_varios_conjuntos_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Redes Neuronales con Keras
#
# En este ejercicio, tu objetivo será entrenar modelos de Redes Neuronales utilizando Keras (y Tensorflow como backend) para familiarizarte con la librería.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib 
import matplotlib.pyplot as plt
import utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using matplotlib backend: agg

# %% [markdown]
# # Entrena un modelo de Redes Neuronales con Keras para varios datasets
#
#
#
# Podés elegir el dataset comentando/descomentando las líneas 9 a 17. Comentá todos los datasets salvo el que quieras usar.
#
# Intenta obtener una buena performance en todos los casos. Prueba activando o no la normalización (últimas líneas) ¿Qué datasets no puede aprender el modelo?

# %%
import tensorflow as tf
import keras
import numpy as np
import utils 
import os

# Selección del dataset; descomenta el que quieras usar
# Datasets en 2D
#dataset = "2_clases_simple.csv"
#dataset = "6_clases_dificil.csv"
#dataset = "moons.csv"
#dataset = "moons_mis-scaled.csv"
dataset = "circulos.csv"

# Dataset con más de 2 dimensiones
# dataset = "iris.csv"
# dataset = "diabetes.csv"

# Carga del dataset
dataset_path=os.path.join("datasets_clasificacion",dataset)
data=np.loadtxt(open(dataset_path, "rb"), delimiter=",", skiprows=1)
x,y=data[:,0:-1],data[:,-1]
# cantidad de ejemplos y dimension de entrada
n,d_in=x.shape
# calcula la cantidad de clases
classes=int(y.max()+1)

print("Información del conjunto de datos:")
print(f"Ejemplos: {n}")
print(f"Variables de entrada: {d_in}")
print(f"Cantidad de clases: {classes}")

# Normalizo las variables de entrada
for i in range(d_in):
    x[:,i]=(x[:,i]-x[:,i].mean())/x[:,i].std()
# Out:
# Información del conjunto de datos:
# Ejemplos: 300
# Variables de entrada: 2
# Cantidad de clases: 2

# %%
# Creación del modelo inicial
print("Inicialización aleatoria del modelo (podes volver a correr esta celda para obtener otros resultados)")

# Creo un modelo Red Neuronal 
modelo = keras.Sequential([
    # input_shape solo en la primer capa
    # Capa con 3 salidas, activación relu
    keras.layers.Dense(3,input_shape=(d_in,), activation='relu'),
    # Capa con 5 salidas, activación tanh
    keras.layers.Dense(5, activation='tanh'),
    #la ultima capa si o si tiene que tener tantas salidas como clases, y softmax 
    keras.layers.Dense(classes, activation='softmax')])

# visualización del modelo inicial (si hay solo 2 variables de entrada)
if d_in==2:
    utils.plot_regresion_logistica2D(modelo,x,y,title=f"Modelo inicial",detail=0.05)



modelo.compile(
  optimizer=keras.optimizers.SGD(lr=0.001), 
  loss='sparse_categorical_crossentropy', 
  # metricas para ir calculando en cada iteracion o batch 
  # Agregamos el accuracy del modelo
  metrics=['accuracy'], 
)

# Entrenamiento del modelo
modelo.fit(x,y,epochs=100,batch_size=16)


# visualización del modelo final (si hay solo 2 variables de entrada)
if d_in==2:
    utils.plot_regresion_logistica2D(modelo,x,y,title=f"Modelo Final",detail=0.05)
# Out:
# Inicialización aleatoria del modelo (podes volver a correr esta celda para obtener otros resultados)
# Epoch 1/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7792 - accuracy: 0.5567
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7767 - accuracy: 0.5567
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7743 - accuracy: 0.5600
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7719 - accuracy: 0.5500
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7696 - accuracy: 0.5400
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7674 - accuracy: 0.5467
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7651 - accuracy: 0.5500
# Epoch 8/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7629 - accuracy: 0.5500
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7608 - accuracy: 0.5533
# Epoch 10/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7587 - accuracy: 0.5567
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7566 - accuracy: 0.5567
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7546 - accuracy: 0.5633
# Epoch 13/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7526 - accuracy: 0.5667
# Epoch 14/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7507 - accuracy: 0.5800
# Epoch 15/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7487 - accuracy: 0.5733
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7468 - accuracy: 0.5767
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7450 - accuracy: 0.5733
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7432 - accuracy: 0.5667
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7414 - accuracy: 0.5667
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7397 - accuracy: 0.5700
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7379 - accuracy: 0.5667
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7363 - accuracy: 0.5700
# Epoch 23/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7346 - accuracy: 0.5633
# Epoch 24/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7331 - accuracy: 0.5600
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7315 - accuracy: 0.5600
# Epoch 26/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7299 - accuracy: 0.5500
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7284 - accuracy: 0.5500
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7269 - accuracy: 0.5500
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7254 - accuracy: 0.5500
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7240 - accuracy: 0.5500
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7226 - accuracy: 0.5500
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7211 - accuracy: 0.5533
# Epoch 33/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7198 - accuracy: 0.5467
# Epoch 34/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7185 - accuracy: 0.5467
# Epoch 35/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7171 - accuracy: 0.5500
# Epoch 36/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7158 - accuracy: 0.5533
# Epoch 37/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7145 - accuracy: 0.5567
# Epoch 38/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7133 - accuracy: 0.5567
# Epoch 39/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7120 - accuracy: 0.5567
# Epoch 40/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7108 - accuracy: 0.5567
# Epoch 41/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7096 - accuracy: 0.5567
# Epoch 42/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7084 - accuracy: 0.5567
# Epoch 43/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7072 - accuracy: 0.5533
# Epoch 44/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7061 - accuracy: 0.5567
# Epoch 45/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7049 - accuracy: 0.5567
# Epoch 46/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7039 - accuracy: 0.5600
# Epoch 47/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7028 - accuracy: 0.5600
# Epoch 48/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7017 - accuracy: 0.5633
# Epoch 49/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7006 - accuracy: 0.5600
# Epoch 50/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6996 - accuracy: 0.5567
# Epoch 51/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6986 - accuracy: 0.5567
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6976 - accuracy: 0.5600
# Epoch 53/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6966 - accuracy: 0.5567
# Epoch 54/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6956 - accuracy: 0.5567
# Epoch 55/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6946 - accuracy: 0.5567
# Epoch 56/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.5500
# Epoch 57/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5533
# Epoch 58/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6918 - accuracy: 0.5533
# Epoch 59/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6909 - accuracy: 0.5567
# Epoch 60/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.5567
# Epoch 61/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6891 - accuracy: 0.5533
# Epoch 62/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5533
# Epoch 63/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.5533
# Epoch 64/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5533
# Epoch 65/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5533
# Epoch 66/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5533
# Epoch 67/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.5533
# Epoch 68/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5567
# Epoch 69/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.5533
# Epoch 70/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.5567
# Epoch 71/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6808 - accuracy: 0.5533
# Epoch 72/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5567
# Epoch 73/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5567
# Epoch 74/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6785 - accuracy: 0.5600
# Epoch 75/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6778 - accuracy: 0.5600
# Epoch 76/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6770 - accuracy: 0.5633
# Epoch 77/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.5633
# Epoch 78/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6756 - accuracy: 0.5667
# Epoch 79/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6749 - accuracy: 0.5667
# Epoch 80/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6742 - accuracy: 0.5633
# Epoch 81/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.5667
# Epoch 82/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6728 - accuracy: 0.5633
# Epoch 83/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6721 - accuracy: 0.5467
# Epoch 84/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6714 - accuracy: 0.5767
# Epoch 85/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6708 - accuracy: 0.5833
# Epoch 86/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6701 - accuracy: 0.5867
# Epoch 87/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6694 - accuracy: 0.5900
# Epoch 88/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6688 - accuracy: 0.5933
# Epoch 89/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6682 - accuracy: 0.5967
# Epoch 90/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6675 - accuracy: 0.5967
# Epoch 91/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6669 - accuracy: 0.6033
# Epoch 92/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6662 - accuracy: 0.6000
# Epoch 93/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6656 - accuracy: 0.6000
# Epoch 94/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.6000
# Epoch 95/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6644 - accuracy: 0.6000
# Epoch 96/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.6000
# Epoch 97/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.6000
# Epoch 98/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6626 - accuracy: 0.6000
# Epoch 99/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6620 - accuracy: 0.6000
# Epoch 100/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6614 - accuracy: 0.6067
